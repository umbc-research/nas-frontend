# %%
from astropy.io import fits
fits_file = fits.open('Capture_00001.fits')
print(fits_file)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x0000017CAD812FD0>]

# %%
image_data = fits_file[0].data
print(image_data)
# Out:
# [[16  0 16 ...  0  0  0]
#  [16  0  0 ...  0 16  0]
#  [ 0  0  0 ...  0 16  0]
#  ...
#  [ 0  0 32 ...  0  0 32]
#  [16 16 16 ... 48 64  0]
#  [ 0  0  0 ...  0 64  0]]

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
plt.figure()
plt.imshow(image_data, origin = 'lower', norm = LogNorm(),)
plt.colorbar()
plt.show()

# %%
header = fits_file[0].header


instrument_name = header.get('INSTRUME', 'N/A')
filter_name = header.get('FILTER', 'N/A')  
date_name = header.get('DATE-AVG', 'N/A')


print("Instrument Name:", instrument_name)
print("Filter:", filter_name)
print("Date-avg:", date_name)
# Out:
# Instrument Name: ZWO ASI2600MM Pro
# Filter: V
# Date-avg: 2024-02-20T03:51:31.7337796
