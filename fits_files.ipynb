# %%
from astropy.io import fits
fits_file = fits.open('19_46_09_comet2023A3_finder_00008.fits')
print(fits_file)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x00000182F745E210>]

# %%
image_data = fits_file[0].data
print(image_data)
# Out:
# [[269 264 283 ... 266 251 273]
#  [269 264 265 ... 254 274 261]
#  [276 280 255 ... 256 279 261]
#  ...
#  [286 274 296 ... 271 255 279]
#  [279 281 283 ... 279 274 289]
#  [277 293 283 ... 273 274 289]]

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
plt.figure()
plt.imshow(image_data, origin = 'lower', norm = LogNorm(), cmap = 'Greys')
plt.colorbar()
plt.show()
